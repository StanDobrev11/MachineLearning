# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.ensemble import VotingClassifier, StackingClassifier

import tensorflow as tf
from keras.models import Sequential

# %% [markdown]
# ## Introduction to Neural Networks
#
# ### Live Demo

# %%
log_reg = LogisticRegression()

# %%
log_regs = [(f"log_reg_{i}", LogisticRegression()) for i in range(1, 21)]

# %%
voting = VotingClassifier(log_regs)
# Out:
# VotingClassifier(estimators=[('log_reg_1', LogisticRegression()),
#                              ('log_reg_2', LogisticRegression()),
#                              ('log_reg_3', LogisticRegression()),
#                              ('log_reg_4', LogisticRegression()),
#                              ('log_reg_5', LogisticRegression()),
#                              ('log_reg_6', LogisticRegression()),
#                              ('log_reg_7', LogisticRegression()),
#                              ('log_reg_8', LogisticRegression()),
#                              ('log_reg_9', LogisticRegression()),
#                              ('log_...
#                              ('log_reg_11', LogisticRegression()),
#                              ('log_reg_12', LogisticRegression()),
#                              ('log_reg_13', LogisticRegression()),
#                              ('log_reg_14', LogisticRegression()),
#                              ('log_reg_15', LogisticRegression()),
# ...

# %%
voting_classifier = [(f"voting_{i}", VotingClassifier(log_regs)) for i in range(5)]

# %%
StackingClassifier(voting_classifier)
# Out:
# StackingClassifier(estimators=[('voting_0',
#                                 VotingClassifier(estimators=[('log_reg_1',
#                                                               LogisticRegression()),
#                                                              ('log_reg_2',
#                                                               LogisticRegression()),
#                                                              ('log_reg_3',
#                                                               LogisticRegression()),
#                                                              ('log_reg_4',
#                                                               LogisticRegression()),
#                                                              ('log_reg_5',
#                                                               LogisticRegression()),
#                                                              ('log_reg_6',
# ...

# %%
 sgd = SGDClassifier(loss='hinge')

# %%
units = [(f"log_reg_{i}", SGDClassifier()) for i in range(1, 21)]

# %%
layer = VotingClassifier(units)

# %%
nn = [(f"voting_{i}", VotingClassifier(units)) for i in range(5)]

# %%
StackingClassifier(nn)
# Out:
# StackingClassifier(estimators=[('voting_0',
#                                 VotingClassifier(estimators=[('log_reg_1',
#                                                               SGDClassifier()),
#                                                              ('log_reg_2',
#                                                               SGDClassifier()),
#                                                              ('log_reg_3',
#                                                               SGDClassifier()),
#                                                              ('log_reg_4',
#                                                               SGDClassifier()),
#                                                              ('log_reg_5',
#                                                               SGDClassifier()),
#                                                              ('log_reg_6',
#                                                               SGDClassifier()),
# ...

# %%
tf.config.list_physical_devices('CPU')
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
